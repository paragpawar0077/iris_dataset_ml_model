# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv('iris.csv')

# %%
X = data.iloc[:, :-1]  # All columns except the last as features
y = data.iloc[:, -1]   # Last column as label

# %%
model = RandomForestClassifier()
model.fit(X, y)
# Out:
# RandomForestClassifier()

# %%
predictions = model.predict(X)  # Predict on the same/new data (for demonstration)
print(predictions)  # Display predictions
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
# ...

# %%
x=[[4.1,2.6,3.9,4]]
pre=model.predict(x)
# Out:
# C:\Users\Parag\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
pre
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
X_new = [5,6,3,4]
y_= np.array(X_new).reshape(2, -1) 
y_
# Out:
# array([[5, 6],
#        [3, 4]])

# %%
# Read Excel and save as CSV
##df = pd.read_excel('iris-test.xlsx')
#df.to_csv('iris-test.csv', index=False)

# %%
dataset = pd.read_csv('iris-test.csv')

# %%
x_test = dataset.iloc[:,:-1]

# %%
predicttions = model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 predicttions = model.predict(x_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:903, in ForestClassifier.predict(self, X)
#     882 def predict(self, X):
#     883     """
#     884     Predict class for X.
#     885
#    (...)
#     901         The predicted classes.
#     902     """
# --> 903     proba = self.predict_proba(X)
#     905     if self.n_outputs_ == 1:
#     906         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:945, in ForestClassifier.predict_proba(self, X)
#     943 check_is_fitted(self)
#     944 # Check data
# --> 945 X = self._validate_X_predict(X)
#     947 # Assign chunk of trees to jobs
#     948 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# ...
